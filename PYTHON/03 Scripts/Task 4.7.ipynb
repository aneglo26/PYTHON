# %% [markdown]
# # Task 4.7

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %% [markdown]
# ## Exercise tasks

# %%
# Defining function
def add_num(x,y):
    sum = x + y
    return sum

# %%
# Run function
add_num(29,11)
# Out:
# 40

# %% [markdown]
# ## Importing df

# %%
path = r'D:\Downloads\Data Analytics\content\Task 4'

# %%
combined_df_46 = pd.read_pickle(os.path.join(path, 'Data', 'combined_df_46.pkl'))

# %%
# Using only the first one million rows
df = combined_df_46[:1000000]

# %% [markdown]
# ## Practicing

# %%
# Defining the function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# Applying the function
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\anegl\AppData\Local\Temp\ipykernel_12884\2918228003.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df['price_range'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# ## Using loc() instead

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\anegl\AppData\Local\Temp\ipykernel_12884\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
# Entire Data Range

# %%
combined_df_46.loc[combined_df_46['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
combined_df_46.loc[(combined_df_46['prices'] <= 15) & (combined_df_46['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
combined_df_46.loc[combined_df_46['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
combined_df_46['price_range_loc'].value_counts(dropna = False)
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## If Statements

# %%
combined_df_46['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %%
result = []

for value in combined_df_46["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
combined_df_46['busiest_day'] = result

# %%
combined_df_46['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %% [markdown]
# # Task 4.7 Exercise

# %% [markdown]
# ## 4.7.2

# %%
def busy_day(row):

  if row['orders_day_of_week'] <= 1:
    return 'Busiest days'
  elif (row['orders_day_of_week'] == 4):
    return 'Slowest days'
  elif row['orders_day_of_week'] == 3:
    return 'Slowest days'
  else: return 'Regularly busy'

# %% [markdown]
# ### This took some time:

# %%
combined_df_46['busiest_days'] = combined_df_46.apply(busy_day, axis=1)

# %%
combined_df_46['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %%
combined_df_46['orders_day_of_week'].value_counts(dropna = False)
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ## 4.7.3

# %%
combined_df_46['busiest_days'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: busiest_days, dtype: int64

# %% [markdown]
# Total orders: 32,404,859 which is the same amount as previously calculated during the practice exercise, meaning that now the data is organized only in 3 segments, instead of 7 days of the week.

# %% [markdown]
# ## 4.7.4

# %% [markdown]
# ### In this case, we have to first check which hours are have more orders

# %%
combined_df_46['time_of_order'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: time_of_order, dtype: int64

# %% [markdown]
# ### Then we have to divide into groups of 8 (24/3), so we have the 'Most orders', 'Average orders' and 'Fewest orders'

# %%
combined_df_46.loc[combined_df_46['time_of_order'] == 7, 'busiest_period_of_day'] = 'Average orders'

# %%
combined_df_46.loc[combined_df_46['time_of_order'] == 8, 'busiest_period_of_day'] = 'Average orders'

# %%
combined_df_46.loc[combined_df_46['time_of_order'] == 23, 'busiest_period_of_day'] = 'Fewest orders'

# %%
combined_df_46.loc[(combined_df_46['time_of_order'] <= 16) & (combined_df_46['time_of_order'] >= 9), 'busiest_period_of_day'] = 'Most orders'

# %%
combined_df_46.loc[(combined_df_46['time_of_order'] <= 6) & (combined_df_46['time_of_order'] >= 0), 'busiest_period_of_day'] = 'Fewest orders'

# %%
combined_df_46.loc[(combined_df_46['time_of_order'] <= 22) & (combined_df_46['time_of_order'] >= 17), 'busiest_period_of_day'] = 'Average orders'

# %% [markdown]
# ## 4.7.5

# %% [markdown]
# ### Frequency

# %%
combined_df_46['busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: busiest_period_of_day, dtype: int64

# %% [markdown]
# ## 4.7.7

# %%
combined_df_46
# Out:
#           order_id  user_id  order_number  orders_day_of_week  time_of_order  \
# 0          2539329        1             1                   2              8
# 1          2398795        1             2                   3              7
# 2           473747        1             3                   3             12
# 3          2254736        1             4                   4              7
# 4           431534        1             5                   4             15
# ...            ...      ...           ...                 ...            ...
# 32404854   1320836   202557            17                   2             15
# 32404855     31526   202557            18                   5             11
# 32404856    758936   203436             1                   2              7
# 32404857   2745165   203436             2                   3              5
# 32404858   3093936   205420             1                   4             14
#
# ...

# %%
combined_df_46.to_pickle(os.path.join(path, 'Data', 'combined_df_47.pkl'))
